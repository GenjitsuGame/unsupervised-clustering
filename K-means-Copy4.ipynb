# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import pandas as pd
import scipy
from numpy import mean, cov
from numpy.linalg import eigh
import math
import sys
import time
import seaborn as sns

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
def plot_graph(k, labels, predicted_labels):
    hist = []
    for i in range(k):
        hist.append([])
    
    for i in range(len(labels)):
        hist[labels[i]].append(predicted_labels[i])

    plt.hist(hist)

# %%
def pca(data):
    cova = cov(data.T) 
    values, vectors = eigh(cova)
    idx = np.argsort(values)[::-1]
    values = np.real(values[idx])
    vectors = np.real(vectors.T[idx])
    return values, vectors

# %%
def kmeans(points, k, epochs=10000, centroids=None):
    begin = int(round(time.time() * 1000))
    last = begin
    not_finished = True
    if centroids is None:
        random_mask = np.random.choice(points.shape[0], k, replace=False)
        centroids = points[random_mask, :]
    epoch = 0
    labels = []
    
    while not_finished and epoch < epochs:
        labels = np.array([np.argmin([scipy.spatial.distance.euclidean(point, centroid) for centroid in centroids]) for point in points])
        not_finished = False

        for i in range(k):
            new_centroid = np.mean(points[np.where(labels == i)], axis=0)
            if not np.all(np.isclose(new_centroid, centroids[i])):
                centroids[i] = new_centroid
                not_finished = True

        if epoch != 0 == 0:
            current = int(round(time.time() * 1000))
            print('{} in {}ms. elapsed : {}ms.'.format(epoch, current - last, current - begin))
            last = current
        epoch = epoch + 1
        
    return labels, centroids


def kmeans_predict(centroids, points):
    return [np.argmin([scipy.spatial.distance.euclidean(point, centroid) for centroid in centroids]) for point in points]

# %%
k = 3
points = []
for i in range(k):
    points.extend((np.random.rand(15, 2)) / 2 + (i - 1.5) * (i - 1.5))

points = np.array(points)
labels, centroids = kmeans(points, k)

plt.scatter(centroids[:, 0], centroids[:, 1])
plt.scatter(points[:, 0], points[:, 1], c=labels)
# Out:
# 1 in 6ms. elapsed : 6ms.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1] * x_train.shape[2])
x_train = x_train.astype('float32') / 255.0
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1] * x_test.shape[2])
x_test = x_test.astype('float32') / 255.0

# %% [markdown]
# Masks to select 0 and 1 labels.
# Only train on 500 elements from 2 selected classes for prototyping purposes.

# %%
mask_0 = np.where(y_train == 0)
mask_1 = np.where(y_train == 1)

# %%
sub_x_train = np.concatenate((x_train[mask_0][:500], x_train[mask_1][:500]))
sub_y_train = np.concatenate((y_train[mask_0][:500], y_train[mask_1][:500]))

# %%
labels, centroids = kmeans(x_train, 11, epochs=100)
# Out:
# 10
# 20
# 30
# 40

# %%
plot_graph(11, y_train, labels.astype('uint8'))

# %%
dims = 2
values, vectors = pca(x_train)
compressed_pca = x_train.dot(vectors[:dims].T)
compressed_pca.shape
# Out:
# (60000, 2)

# %%
labels, centroids = kmeans(compressed_pca, 10, epochs=100)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70

# %%
plot_graph(10, y_train, labels.astype('uint8'))

# %% [markdown]
# ## Autoencoder

# %%
from keras.layers import Input, Dense
from keras.models import Model

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
encoding_dim = 32  

input_img = Input(shape=(x_train.shape[1],))

encoded = Dense(encoding_dim, activation='relu')(input_img)

decoded = Dense(x_train.shape[1], activation='sigmoid')(encoded)

autoencoder = Model(input_img, decoded)

encoder = Model(input_img, encoded)


encoded_input = Input(shape=(encoding_dim,))

decoder_layer = autoencoder.layers[-1]

decoder = Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adadelta', loss='binary_crossentrop
50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0992 - acc: 0.8138 - val_loss: 0.0976 - val_acc: 0.8129
# Epoch 34/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0991 - acc: 0.8138 - val_loss: 0.0975 - val_acc: 0.8129
# Epoch 35/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0991 - acc: 0.8138 - val_loss: 0.0975 - val_acc: 0.8129
# Epoch 36/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0990 - acc: 0.8138 - val_loss: 0.0974 - val_acc: 0.8129
# Epoch 37/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0989 - acc: 0.8138 - val_loss: 0.0973 - val_acc: 0.8129
# Epoch 38/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0989 - acc: 0.8138 - val_loss: 0.0973 - val_acc: 0.8129
# Epoch 39/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0988 - acc: 0.8138 - val_loss: 0.0972 - val_acc: 0.8129
# Epoch 40/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0987 - acc: 0.8138 - val_loss: 0.0972 - val_acc: 0.8129
# Epoch 41/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0986 - acc: 0.8138 - val_loss: 0.0971 - val_acc: 0.8129
# Epoch 42/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0986 - acc: 0.8138 - val_loss: 0.0970 - val_acc: 0.8129
# Epoch 43/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.0985 - acc: 0.8138 - val_loss: 0.0970 - val_acc: 0.8129
# Epoch 44/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0984 - acc: 0.8138 - val_loss: 0.0969 - val_acc: 0.8129
# Epoch 45/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0984 - acc: 0.8138 - val_loss: 0.0968 - val_acc: 0.8130
# Epoch 46/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.0983 - acc: 0.8138 - val_loss: 0.0968 - val_acc: 0.8129
# Epoch 47/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.0982 - acc: 0.8138 - val_loss: 0.0967 - val_acc: 0.8130
# Epoch 48/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0982 - acc: 0.8138 - val_loss: 0.0966 - val_acc: 0.8129
# Epoch 49/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0981 - acc: 0.8138 - val_loss: 0.0966 - val_acc: 0.8130
# Epoch 50/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.0980 - acc: 0.8139 - val_loss: 0.0965 - val_acc: 0.8130

# %%
encoding_dim = 2  

dims = x_train.shape[1]
values, vectors = pca(x_train)
compressed_pca = x_train.dot(vectors[:dims].T)

input_img = Input(shape=(x_train.shape[1],))

encoded = Dense(encoding_dim, activation='relu')(input_img)

decoded = Dense(x_train.shape[1], activation='sigmoid')(encoded)

autoencoder = Model(input_img, decoded)

encoder = Model(input_img, encoded)


encoded_input = Input(shape=(encoding_dim,))

decoder_layer = autoencoder.layers[-1]

decoder = Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=['accuracy'])

# %%
compressed_pca.shape
# Out:
# (60000, 784)

# %%
autoencoder.fit(compressed_pca, compressed_pca,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0340 - acc: 0.0186 - val_loss: 0.5888 - val_acc: 0.8007
# Epoch 2/50
# 60000/60000 [==============================] - 2s 32us/step - loss: -0.2782 - acc: 0.0204 - val_loss: 0.5629 - val_acc: 0.8009
# Epoch 3/50
# 60000/60000 [==============================] - 2s 28us/step - loss: -0.2881 - acc: 0.0204 - val_loss: 0.5495 - val_acc: 0.8012
# Epoch 4/50
# 60000/60000 [==============================] - 2s 28us/step - loss: -0.2915 - acc: 0.0204 - val_loss: 0.5419 - val_acc: 0.8016
# Epoch 5/50
# 60000/60000 [==============================] - 2s 31us/step - loss: -0.2935 - acc: 0.0204 - val_loss: 0.5370 - val_acc: 0.8019
# Epoch 6/50
# 60000/60000 [==============================] - 2s 36us/step - loss: -0.2956 - acc: 0.0204 - val_loss: 0.5335 - val_acc: 0.8020
# Epoch 7/50
# 60000/60000 [==============================] - 2s 33us/step - loss: -0.2991 - acc: 0.0204 - val_loss: 0.5306 - val_acc: 0.8024
# Epoch 8/50
# 60000/60000 [==============================] - 2s 36us/step - loss: -0.3050 - acc: 0.0204 - val_loss: 0.5281 - val_acc: 0.8031
# Epoch 9/50
# 60000/60000 [==============================] - 2s 38us/step - loss: -0.3120 - acc: 0.0204 - val_loss: 0.5258 - val_acc: 0.8037
# Epoch 10/50
# 60000/60000 [==============================] - 2s 30us/step - loss: -0.3173 - acc: 0.0204 - val_loss: 0.5236 - val_acc: 0.8039
# Epoch 11/50
# 60000/60000 [==============================] - 2s 30us/step - loss: -0.3207 - acc: 0.0204 - val_loss: 0.5217 - val_acc: 0.8038
# Epoch 12/50
# 60000/60000 [==============================] - 2s 34us/step - loss: -0.3225 - acc: 0.0204 - val_loss: 0.5200 - val_acc: 0.8040
# Epoch 13/50
# 60000/60000 [==============================] - 2s 35us/step - loss: -0.3236 - acc: 0.0204 - val_loss: 0.5184 - val_acc: 0.8040
# Epoch 14/50
# 60000/60000 [==============================] - 2s 39us/step - loss: -0.3244 - acc: 0.0204 - val_loss: 0.5169 - val_acc: 0.8040
# Epoch 15/50
# 60000/60000 [==============================] - 2s 37us/step - loss: -0.3250 - acc: 0.0204 - val_loss: 0.5156 - val_acc: 0.8040
# Epoch 16/50
# 60000/60000 [==============================] - 2s 33us/step - loss: -0.3255 - acc: 0.0204 - val_loss: 0.5144 - val_acc: 0.8045
# Epoch 17/50
# 60000/60000 [==============================] - 2s 29us/step - loss: -0.3260 - acc: 0.0204 - val_loss: 0.5132 - val_acc: 0.8044
# Epoch 18/50
# 60000/60000 [==============================] - 2s 29us/step - loss: -0.3263 - acc: 0.0204 - val_loss: 0.5120 - val_acc: 0.8042
# Epoch 19/50
# 60000/60000 [==============================] - 2s 41us/step - loss: -0.3266 - acc: 0.0204 - val_loss: 0.5109 - val_acc: 0.8047
# Epoch 20/50
# 60000/60000 [==============================] - 2s 29us/step - loss: -0.3269 - acc: 0.0204 - val_loss: 0.5098 - val_acc: 0.8046
# Epoch 21/50
# 60000/60000 [==============================] - 2s 29us/step - loss: -0.3272 - acc: 0.0204 - val_loss: 0.5088 - val_acc: 0.8051
# Epoch 22/50
# 60000/60000 [==============================] - 2s 34us/step - loss: -0.3274 - acc: 0.0204 - val_loss: 0.5079 - val_acc: 0.8051
# Epoch 23/50
# 60000/60000 [==============================] - 2s 36us/step - loss: -0.3276 - acc: 0.0204 - val_loss: 0.5068 - val_acc: 0.8051
# Epoch 24/50
# 60000/60000 [==============================] - 2s 35us/step - loss: -0.3278 - acc: 0.0204 - val_loss: 0.5060 - val_acc: 0.8051
# Epoch 25/50
# 60000/60000 [==============================] - 2s 33us/step - loss: -0.3280 - acc: 0.0204 - val_loss: 0.5051 - val_acc: 0.8051
# Epoch 26/50
# 60000/60000 [==============================] - 2s 37us/step - loss: -0.3281 - acc: 0.0204 - val_loss: 0.5043 - val_acc: 0.8051
# Epoch 27/50
# 60000/60000 [==============================] - 2s 32us/step - loss: -0.3283 - acc: 0.0204 - val_loss: 0.5035 - val_acc: 0.8051
# Epoch 28/50
# 60000/60000 [==============================] - 2s 34us/step - loss: -0.3284 - acc: 0.0204 - val_loss: 0.5027 - val_acc: 0.8051
# Epoch 29/50
# 60000/60000 [==============================] - 2s 34us/step - loss: -0.3285 - acc: 0.0204 - val_loss: 0.5019 - val_acc: 0.8051
# Epoch 30/50
# 60000/60000 [==============================] - 2s 32us/step - loss: -0.3286 - acc: 0.0204 - val_loss: 0.5012 - val_acc: 0.8051
# Epoch 31/50
# 60000/60000 [==============================] - 2s 34us/step - loss: -0.3287 - acc: 0.0204 - val_loss: 0.5004 - val_acc: 0.8050
# Epoch 32/50
# 60000/60000 [==============================] - 2s 33us/step - loss: -0.3288 - acc: 0.0204 - val_loss: 0.4997 - val_acc: 0.8051
# Epoch 33/50
# 60000/60000 [==============================] - 2s 33us/step - loss: -0.3289 - acc: 0.0204 - val_loss: 0.4991 - val_acc: 0.8050
# Epoch 34/50
# 60000/60000 [==============================] - 2s 36us/step - loss: -0.3290 - acc: 0.0204 - val_loss: 0.4984 - val_acc: 0.8050
# Epoch 35/50
# 60000/60000 [==============================] - 2s 39us/step - loss: -0.3291 - acc: 0.0204 - val_loss: 0.4977 - val_acc: 0.8050
# Epoch 36/50
# 60000/60000 [==============================] - 2s 34us/step - loss: -0.3292 - acc: 0.0204 - val_loss: 0.4971 - val_acc: 0.8050
# Epoch 37/50
# 60000/60000 [==============================] - 2s 36us/step - loss: -0.3293 - acc: 0.0204 - val_loss: 0.4965 - val_acc: 0.8050
# Epoch 38/50
# 60000/60000 [==============================] - 2s 40us/step - loss: -0.3293 - acc: 0.0204 - val_loss: 0.4958 - val_acc: 0.8050
# Epoch 39/50
# 60000/60000 [==============================] - 2s 37us/step - loss: -0.3294 - acc: 0.0204 - val_loss: 0.4953 - val_acc: 0.8050
# Epoch 40/50
# 60000/60000 [==============================] - 2s 36us/step - loss: -0.3295 - acc: 0.0204 - val_loss: 0.4946 - val_acc: 0.8050
# Epoch 41/50
# 60000/60000 [==============================] - 2s 34us/step - loss: -0.3295 - acc: 0.0204 - val_loss: 0.4941 - val_acc: 0.8050
# Epoch 42/50
# 60000/60000 [==============================] - 2s 35us/step - loss: -0.3296 - acc: 0.0204 - val_loss: 0.4936 - val_acc: 0.8050
# Epoch 43/50
# 60000/60000 [==============================] - 2s 36us/step - loss: -0.3297 - acc: 0.0204 - val_loss: 0.4930 - val_acc: 0.8050
# Epoch 44/50
# 60000/60000 [==============================] - 2s 37us/step - loss: -0.3297 - acc: 0.0204 - val_loss: 0.4924 - val_acc: 0.8050
# Epoch 45/50
# 60000/60000 [==============================] - 2s 40us/step - loss: -0.3298 - acc: 0.0204 - val_loss: 0.4919 - val_acc: 0.8050
# Epoch 46/50
# 60000/60000 [==============================] - 2s 37us/step - loss: -0.3298 - acc: 0.0204 - val_loss: 0.4913 - val_acc: 0.8050
# Epoch 47/50
# 60000/60000 [==============================] - 2s 38us/step - loss: -0.3299 - acc: 0.0204 - val_loss: 0.4909 - val_acc: 0.8050
# Epoch 48/50
# 60000/60000 [==============================] - 2s 36us/step - loss: -0.3299 - acc: 0.0204 - val_loss: 0.4903 - val_acc: 0.8050
# Epoch 49/50
# 60000/60000 [==============================] - 2s 36us/step - loss: -0.3300 - acc: 0.0204 - val_loss: 0.4898 - val_acc: 0.8050
# Epoch 50/50
# 60000/60000 [==============================] - 2s 35us/step - loss: -0.3300 - acc: 0.0204 - val_loss: 0.4893 - val_acc: 0.8050

# %% [markdown]
# ## Listings AirBnB
#
# This dataset contains ~250k AirBnB listings with the property type as label a curated list of features.
#
# The data prep has been done in a separate notebook.
# Features have been selected according to our intuition and encoded in one hot vectors.
#
# ### PCA 2D

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df_listings = pd.read_csv('embedded_listings.csv', sep=';')

# %%
df_listings
# Out:
#              Property Type  Accommodates  Bathrooms  Bedrooms  Beds  \
# 0                Apartment           2.0        1.0       1.0   1.0
# 1                Apartment           2.0        1.0       1.0   1.0
# 2          Bed & Breakfast           2.0        2.0       1.0   2.0
# 3          Bed & Breakfast           1.0        1.5       1.0   1.0
# 4                Apartment           2.0        1.0       1.0   1.0
# 5                Apartment           4.0        2.0       2.0   2.0
# 6       Serviced apartment          12.0        2.5       7.0   7.0
# 7              Condominium           2.0        1.0       1.0   1.0
# 8                Apartment           2.0        1.0       1.0   2.0
# 9                    House           5.0        1.0       3.0   5.0
# 10                   House           1.0        1.0       1.0   1.0
# 11                   House           4.0        1.0       4.0   4.0
# 12               Apartment           2.0        1.0       0.0   2.0
# 13                  Chalet           4.0        1.0       2.0   4.0
# 14                    Boat           4.0        1.0       2.0   4.0
# 15                   House           2.0        1.5       1.0   1.0
# 16                   House           2.0        1.0       1.0   1.0
# 17                   House           4.0        1.5       2.0   2.0
# 18                   House           4.0        1.0       3.0   4.0
# 19               Apartment           2.0        1.0       1.0   1.0
# 20               Apartment           4.0        1.0       2.0   2.0
# 21               Apartment           4.0        1.0       2.0   2.0
# 22               Apartment           2.0        1.0       1.0   1.0
# 23               Apartment           2.0        1.0       1.0   1.0
# 24               Apartment           3.0        1.5       2.0   2.0
# 25               Apartment           2.0        1.5       1.0   1.0
# 26               Apartment           2.0        1.0       1.0   1.0
# 27               Apartment           2.0        1.5       0.0   1.0
# 28               Apartment           2.0        1.0       1.0   2.0
# 29               Apartment           4.0        1.0       1.0   2.0
# ...                    ...           ...        ...       ...   ...
# 255759           Apartment           2.0        1.0       0.0   1.0
# 255760           Apartment           5.0        1.5       2.0   2.0
# 255761           Apartment           2.0        1.0       1.0   1.0
# 255762                Loft           2.0        1.0       1.0   1.0
# 255763           Townhouse           3.0        3.5       1.0   2.0
# 255764           Apartment           1.0        1.0       1.0   1.0
# 255765           Apartment           2.0        1.0       0.0   1.0
# 255766           Apartment           4.0        1.0       2.0   5.0
# 255767           Apartment           4.0        1.0       2.0   2.0
# 255768           Apartment           2.0        1.0       1.0   1.0
# 255769           Apartment           2.0        1.0       1.0   1.0
# 255770           Apartment           2.0        1.0       1.0   1.0
# 255776                       0              0                  1
# 255777                       0              0                  1
# 255778                       0              0                  1
# 255779                       0              0                  1
# 255780                       0              0                  1
# 255781                       0              0                  1
# 255782                       0              0                  1
# 255783                       0              0                  1
# 255784                       0              0                  1
# 255785                       0              0                  1
# 255786                       0              0                  1
# 255787                       0              0                  1
# 255788                       0              0                  1
#
#         Property Type Labels
# 0                          0
# 1                          0
# 2                          1
# 3                          1
# 4                          0
# 5                          0
# 6                         29
# 7                         11
# 8                          0
# 9                         18
# 10                        18
# 11                        18
# 12                         0
# 13                        10
# 14                         2
# 15                        18
# 16                        18
# 17                        18
# 18                        18
# 19                         0
# 20                         0
# 21                         0
# 22                         0
# 23                         0
# 24                         0
# 25                         0
# 26                         0
# 27                         0
# 28                         0
# 29                         0
# ...                      ...
# 255759                     0
# 255760                     0
# 255761                     0
# 255762                    24
# 255763                    33
# 255764                     0
# 255765                     0
# 255766                     0
# 255767                     0
# 255768                     0
# 255769                     0
# 255770                     0
# 255771                     0
# 255772                     0
# 255773                     0
# 255774                     0
# 255775                     0
# 255776                     0
# 255777                     0
# 255778                     0
# 255779                     0
# 255780                     0
# 255781                     0
# 255782                     0
# 255783                     0
# 255784                     0
# 255785                     0
# 255786                     0
# 255787                     0
# 255788                     0
#
# [255789 rows x 146 columns]

# %%
labels = ['Property Type']
encoded_labels = ['Property Type Labels']
df_features = df_listings.drop(columns=labels + encoded_labels)

# %%
values, vectors = pca(df_features)

# %%
dims = 2
compressed_pca = df_features.dot(vectors[:dims].T)

# %%
compressed_pca.loc[:, 'labels'] = df_listings[labels].values

# %%
compressed_pca
# Out:
#                 0         1              labels
# 0        2.824708  1.306713           Apartment
# 1        2.806856  1.341699           Apartment
# 2        3.297086  2.733203     Bed & Breakfast
# 3        1.941257  2.614572     Bed & Breakfast
# 4        2.828188  2.897780           Apartment
# 5        5.312782  0.965708           Apartment
# 6       15.479468 -0.469430  Serviced apartment
# 7        2.913957  3.181689         Condominium
# 8        3.159152  0.002266           Apartment
# 9        7.900795  1.649043               House
# 10       1.786059  0.887852               House
# 11       6.878558  1.262828               House
# 12       2.936041  2.543669           Apartment
# 13       6.205292  2.345955              Chalet
# 14       6.266673  1.933302                Boat
# 15       2.705093  2.410276               House
# 16       2.556364  0.933953               House
# 17       5.285086  2.204285               House
# 18       6.558802  1.594321               House
# 19       2.766597  1.541866           Apartment
# 20       5.264216  2.368672           Apartment
# 21       5.179542  0.996959           Apartment
# 22       2.791564  1.978102           Apartment
# 23       2.773764  0.796173           Apartment
# 24       4.521712  1.396446           Apartment
# 25       2.893321  2.487835           Apartment
# 26       2.544620  0.866484           Apartment
# 27       2.641457  1.680998           Apartment
# 28       3.115576  2.455442           Apartment
# 29       4.975538  2.289352           Apartment
# ...           ...       ...                 ...
# 255759   2.369668  0.460466           Apartment
# 255760   6.122113  3.002880           Apartment
# 255761   2.756627  2.582743           Apartment
# 255762   2.674660  0.545998                Loft
# 255763   4.275473  2.335011           Townhouse
# 255764   1.708640  0.259981           Apartment
# 255765   2.428317  1.594119           Apartment
# 255766   6.557599  1.399115           Apartment
# 255767   5.078452  1.130438           Apartment
# 255768   2.582826 -0.146805           Apartment
# 255769   2.606917  0.814983           Apartment
# 255770   2.772526  3.257017           Apartment
# 255771   6.723395  2.520124           Apartment
# 255772   3.043667  0.515551           Apartment
# 255773   2.523518  0.381557           Apartment
# 255774   1.797362  1.991010           Apartment
# 255775   4.278781  3.515062           Apartment
# 255776   2.763391  3.131617           Apartment
# 255777   2.512403  2.804227           Apartment
# 255778  10.082083  3.490106           Apartment
# 255779   1.878738  2.779173           Apartment
# 255780   2.908604  2.183406           Apartment
# 255781   4.175376  3.332426           Apartment
# 255782   5.216946  2.240337           Apartment
# 255783   2.798701  1.212202           Apartment
# 255784   2.358167  1.389305           Apartment
# 255785   5.178282  2.052586           Apartment
# 255786   2.452144  2.203969           Apartment
# 255787   2.775364  0.966797           Apartment
# 255788   7.118938  3.470740           Apartment
#
# [255789 rows x 3 columns]

# %%
compressed_pca = compressed_pca.rename(columns={0: 'x', 1:'y'})

# %%
sns.lmplot(x='x', y='y', data=compressed_pca, hue='labels', fit_reg=False)

# %% [markdown]
# ### Train/Test split autoencoder

# %%
x_train, x_test, y_train, y_test = train_test_split(df_features, df_listings.loc[:, encoded_labels], test_size=0.3)

# %%
labels, centroids = kmeans(x_train.as_matrix(), y_train.nunique().item(), epochs=10, centroids=x_train.iloc[np.random.choice(x_train.shape[0], y_train.nunique().item(), replace=False), :].as_matrix())

# %%
encoding_dim = 2

input_img = Input(shape=(x_train.shape[1],))

encoded = Dense(encoding_dim, activation='relu')(input_img)

decoded = Dense(x_train.shape[1], activation='sigmoid')(encoded)

autoencoder = Model(input_img, decoded)

encoder = Model(input_img, encoded)


encoded_input = Input(shape=(encoding_dim,))

decoder_layer = autoencoder.layers[-1]

decoder = Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adadelta', loss='mean_squared_error')

# %%
autoencoder.fit(x_test.as_matrix(), x_test.as_matrix(),
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test.as_matrix(), x_test.as_matrix()))
# Out:
# Train on 76737 samples, validate on 76737 samples
# Epoch 1/50
# 76737/76737 [==============================] - 1s 19us/step - loss: 0.1983 - val_loss: 0.1513
# Epoch 2/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1508 - val_loss: 0.1505
# Epoch 3/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1504 - val_loss: 0.1503
# Epoch 4/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1502 - val_loss: 0.1501
# Epoch 5/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1500 - val_loss: 0.1500
# Epoch 6/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1499 - val_loss: 0.1499
# Epoch 7/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1498 - val_loss: 0.1498
# Epoch 8/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1497 - val_loss: 0.1497
# Epoch 9/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1496 - val_loss: 0.1496
# Epoch 10/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1495 - val_loss: 0.1495
# Epoch 11/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1494 - val_loss: 0.1494
# Epoch 12/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1494 - val_loss: 0.1493
# Epoch 13/50
# 76737/76737 [==============================] - 1s 16us/step - loss: 0.1493 - val_loss: 0.1492
# Epoch 14/50
# 76737/76737 [==============================] - 1s 16us/step - loss: 0.1492 - val_loss: 0.1491
# Epoch 15/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.1491 - val_loss: 0.1490
# Epoch 16/50
# 76737/76737 [==============================] - 1s 16us/step - loss: 0.1490 - val_loss: 0.1490
# Epoch 17/50
# 76737/76737 [==============================] - 1s 15us/step - loss: 0.
# Epoch 49/50
# 76737/76737 [==============================] - 1s 18us/step - loss: 0.1455 - val_loss: 0.1455
# Epoch 50/50
# 76737/76737 [==============================] - 1s 19us/step - loss: 0.1454 - val_loss: 0.1454

# %%
df_predict = y_test.join(df_listings[labels], how='inner')
predict = encoder.predict(x_test.as_matrix())
df_predict.loc[:, 'x'] = predict[:, 0]
df_predict.loc[:, 'y'] = predict[:, 1]

# %%
sns.lmplot(x='x', y='y', data=df_predict, hue='Property Type', fit_reg=False)

# %% [markdown]
# ### Train/Test split PCA into 2D autoencoder

# %%
dims = df_features.shape[1]
compressed_pca = x_train.dot(vectors[:dims].T)

# %%
compressed_pca
# Out:
#               0         1         2         3         4         5         6    \
# 128818   2.696164  1.157528 -0.374525  0.060950  0.972563  0.163504  0.330276
# 219763   2.713348  1.778886 -0.119122  0.614160 -0.092626 -0.707604 -0.176441
# 14458    8.359192  2.053718 -0.992257 -0.388449  1.151703 -0.281788 -0.437545
# 197556   2.811009  1.842475 -0.248878  0.804961  0.222359 -1.115492 -0.183104
# 77747    2.545228  0.789349  0.314604  0.548584  0.401055  0.622201  0.351151
# 47574    5.304870  1.946785 -0.248047  1.105277  0.959605 -1.006295  0.716874
# 143513   2.846123  2.925852 -0.384659  0.511367  1.652364 -0.668382  0.253556
# 114331   2.820509  1.737883 -0.392389  0.296755  1.770704 -0.273561  0.780235
# 47670    2.611124  2.235346  0.363605  0.893039  0.726762  0.160872 -0.074169
# 237986   3.557135  2.103244 -0.339921  1.526587 -0.021992 -1.197209 -0.236695
# 105873   4.408718  2.036558 -1.197574  0.762976  0.501560 -0.402397  0.542049
# 4846     2.709652  1.019311 -0.137651  2.003379  2.914300  0.109002 -0.563821
# 212530  12.750732  0.194803  1.227419  1.482884  0.842323 -1.632282  0.707483
# 42915    2.699879  2.159294  0.624141  0.937596  0.329568  0.039009  0.176449
# 254582   2.546979  0.267788 -0.051158  1.205231  1.554111  0.066920 -0.055077
# 37030    1.747023  0.217386  0.689101  0.991219  0.532717 -0.592259  0.246673
# 137783  15.196280  2.765766  0.171572  1.643853  0.460342  0.078616 -0.082003
# 114429   5.255914  2.704718  0.136176  0.528257  0.064544  0.358349  0.395214
# 236030   2.716396  0.404413 -0.701397  0.581180  1.721486 -0.151389  0.135025
# 26475    4.755858  0.796016 -0.589624 -0.012754  0.264733  0.523293 -0.088192
# 114566   4.961825  1.606853 -0.777939  0.862455  0.650575 -1.061342 -0.398956
# 140947   4.071643  0.500387 -0.525325  0.102488  0.666332 -1.578017  0.179270
# 18444    3.495292  0.921528 -1.059961  0.282452  0.949216 -0.821916  0.564000
# 66801    2.837897  2.436319 -0.142849 -0.217776  1.130156 -0.206465  0.716949
# 46569    1.839168  0.585257  0.647536  1.063906  0.598917 -0.965687  0.221196
# 188138   1.939137  1.297301  0.407790  0.444053  0.949929 -0.759511  0.579495
# 18721    2.633499  2.071245  0.444765  0.488734  0.895648  0.350734  0.778805
# 136182   2.362714  0.480893 -0.872386  0.316005  1.486112  0.366413 -1.016218
# 47574  -0.240663 -0.286384 -0.432396    ...    -0.000141  0.000078
# 143513 -0.269018 -0.366888 -0.722131    ...    -0.000159 -0.000046
# 114331  0.127832  0.441254  0.049954    ...    -0.000176  0.000025
# 47670  -0.899072 -0.477461  0.501121    ...    -0.000146 -0.000070
# 237986 -1.064199  0.475175  0.274549    ...    -0.000087  0.000015
# 105873 -0.957831  0.506153 -0.086096    ...    -0.000221 -0.000018
# 4846   -0.833433 -0.180690  0.385085    ...    -0.000813 -0.000097
# 212530 -1.120724  0.104855  0.715543    ...    -0.000372  0.000043
# 42915  -0.337370 -0.545526  0.190081    ...    -0.000057  0.000044
# 254582 -0.821278 -0.286634  0.044377    ...     0.002762 -0.000069
# 37030  -0.563617 -0.532202  0.347423    ...    -0.000056  0.000025
# 137783 -0.493112 -0.523337 -0.330017    ...     0.000015 -0.000019
# 114429  0.444899 -0.168963  0.923955    ...     0.000090  0.000197
# 236030  0.274692  0.157354  0.307052    ...     0.000041  0.000015
# 26475  -0.191828  0.099996  0.185472    ...    -0.000304 -0.000082
# 114566 -0.682218  0.349209  0.548706    ...    -0.000220 -0.000142
# 140947 -0.885195 -0.438549 -0.040398    ...    -0.000205 -0.000033
# 18444  -1.176299 -0.201371 -0.004572    ...    -0.000231 -0.000029
# 66801  -0.816713 -0.427672 -0.194242    ...    -0.000157  0.000130
# 46569  -0.706587 -0.665755  0.519555    ...    -0.000151  0.000139
# 188138 -0.172710  0.236062  0.368950    ...    -0.000400 -0.000037
# 18721  -0.858307  0.504749  0.261372    ...    -0.000015  0.000048
# 136182 -0.227230 -0.385972  0.507064    ...     0.001335 -0.000146
# 117953 -1.494571  0.098743  0.709959    ...    -0.000104 -0.000073
# 109594  0.186964  0.112172 -0.339504    ...    -0.000287  0.000142
# ...          ...       ...       ...    ...          ...       ...
# 178587 -0.379075 -0.546746 -0.143127    ...     0.000695 -0.000096
# 148977 -0.993386 -0.614388 -1.009016    ...    -0.000081 -0.000049
# 160088 -0.847054  0.438444 -0.059727    ...    -0.000152 -0.000411
# 30508  -0.750154 -0.439633 -0.057773    ...    -0.000100  0.000105
# 105186  0.158022 -0.738736 -0.245750    ...     0.000141  0.000047
# 13010  -0.194608  0.566533  0.096457    ...    -0.000193  0.000105
# 238847 -0.365629 -0.328283  0.450239    ...     0.000153 -0.000025
# 1646    0.630877  0.769548 -0.444708    ...    -0.000030  0.000260
# 185866 -0.691171 -0.172427 -0.511603    ...     0.000128 -0.000148
# 92756   0.331019  0.626531 -0.785611    ...    -0.000176  0.000058
# 71656  -0.678835  0.091394 -0.269198    ...    -0.000088 -0.000028
# 152230 -1.075604  0.089542 -0.439951    ...    -0.001267 -0.000133
# 163599 -0.933141 -0.259239 -0.369645    ...    -0.000009 -0.000038
# 151298  0.066695  0.226175  0.050170    ...    -0.000199 -0.000061
# 66183  -0.964623 -0.273189 -0.486385    ...     0.000007 -0.000131
# 45637   0.075240  0.269153 -0.124557    ...    -0.000255 -0.000003
# 238848 -1.142609  0.155892  1.238594    ...     0.000045  0.000022
# Epoch 2/50
# 179052/179052 [==============================] - 1s 6us/step - loss: 0.2001
# Epoch 3/50
# 179052/179052 [==============================] - 1s 6us/step - loss: 0.2001
# Epoch 4/50
# 179052/179052 [==============================] - 1s 6us/step - loss: 0.2001
# Epoch 5/50
# 179052/179052 [==============================] - 1s 7us/step - loss: 0.2001
# Epoch 6/50
# 179052/179052 [==============================] - 1s 6us/step - loss: 0.2001
# Epoch 7/50
# 179052/179052 [==============================] - 1s 7us/step - loss: 0.2000
# Epoch 8/50
# 179052/179052 [==============================] - 1s 7us/step - loss: 0.2000
# Epoch 9/50
# 179052/179052 [==============================] - 1s 7us/step - loss: 0.2000
# Epoch 10/50
# 179052/179052 [==============================] - 1s 7us/step - loss: 0.2000
# Epoch 11/50
# 179052/179052 [==============================] - 1s 7us/step - loss: 0.2000
# Epoch 12/50
# 179052/179052 [==============================] - 1s 7us/step - loss: 0.2000
# Epoch 13/50
# 179052/179052 [==============================] - 1s 8us/step - loss: 0.2000
# Epoch 14/50
# 179052/179052 [==============================] - 2s 8us/step - loss: 0.2000
# Epoch 15/50
# 179052/179052 [==============================] - 2s 10us/step - loss: 0.2000
# Epoch 16/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 17/50
# 179052/179052 [==============================] - 2s 10us/step - loss: 0.2000
# Epoch 18/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 19/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 20/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 21/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 22/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 23/50
# 179052/179052 [==============================] - 1s 8us/step - loss: 0.2000
# Epoch 24/50
# 179052/179052 [==============================] - 1s 8us/step - loss: 0.2000
# Epoch 25/50
# 179052/179052 [==============================] - 1s 8us/step - loss: 0.2000
# Epoch 26/50
# 179052/179052 [==============================] - 1s 8us/step - loss: 0.2000
# Epoch 27/50
# 179052/179052 [==============================] - 1s 8us/step - loss: 0.2000
# Epoch 28/50
# 179052/179052 [==============================] - 1s 8us/step - loss: 0.2000
# Epoch 29/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 30/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 31/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 32/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 33/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 34/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.2000
# Epoch 35/50
# 179052/179052 [==============================] - 1s 8us/step - loss: 0.1999
# Epoch 36/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 37/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 38/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 39/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 40/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 41/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 42/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 43/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 44/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 45/50
# 179052/179052 [==============================] - 2s 10us/step - loss: 0.1999
# Epoch 46/50
# 179052/179052 [==============================] - 2s 10us/step - loss: 0.1999
# Epoch 47/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 48/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 49/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999
# Epoch 50/50
# 179052/179052 [==============================] - 2s 9us/step - loss: 0.1999

# %%
dims = df_features.shape[1]
compressed_pca = x_test.dot(vectors[:dims].T)
df_predict = y_test.join(df_listings[labels], how='inner')
predict = encoder.predict(compressed_pca.as_matrix())
df_predict.loc[:, 'x'] = predict[:, 0]
df_predict.loc[:, 'y'] = predict[:, 1]

# %%
sns.lmplot(x='x', y='y', data=df_predict, hue='Property Type', fit_reg=False)
